# %%
from torchvision import transforms
import matplotlib.pyplot as plt
from PIL import Image

# %%
T = transforms.RandomAffine(degrees=0, scale=(0.5, 1))

image = Image.open(r"dataset\TrainDataset\images\cju2rkjfwoxys0993x768l1j2.png")

# %%
image
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=597x401 at 0x13EF424CBB0>

# %%
T(image)
# Out:
# <PIL.Image.Image image mode=RGB size=597x401 at 0x13EF424C2B0>

# %%
import torchvision
torchvision.__version__
# Out:
# '0.12.0'

# %%
from torch.utils.tensorboard import SummaryWriter
writer = SummaryWriter()

# %%
writer.add_scalars('Test dice', {
    "Set1": 1,
    "Set2": 2,
    "Set3": 3
}, global_step=1)

# %%
writer.add_scalars('Test dice', {
    "Set1": 2,
    "Set2": 2,
    "Set3": 1
}, global_step=2)
